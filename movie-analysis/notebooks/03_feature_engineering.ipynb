# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/imdb_clean.csv")

# %%
#print("Oldest Movies Order : \n",df.sort_values(["release_year"]))

#print("Latest Movies Order : \n",df.sort_values(["release_year"], ascending=False))

#print("Hit Movies in Order : \n",df.sort_values(["rating"], ascending=False))

#print("Top Hit Movies : \n",df.loc[df["rating"] >= 9.0])

print(df.shape)

print("Top Flop Movies : \n",df.loc[df["rating"] <= 7.6])
# Out:
# (1000, 8)
# Top Flop Movies :
#                                       title            director  release_year  \
# 926               Avatar: The Way of Water       James Cameron          2022
# 927  Harry Potter and the Sorcerer's Stone      Chris Columbus          2001
# 928          Once Upon a Time in Hollywood   Quentin Tarantino          2019
# 929                        American Psycho         Mary Harron          2000
# 930                      The Fifth Element          Luc Besson          1997
# ..                                     ...                 ...           ...
# 995                 A Very Long Engagement  Jean-Pierre Jeunet          2004
# 996                                  Shine         Scott Hicks          1996
# 997                              Philomena      Stephen Frears          2013
# 998                      The Invisible Man         James Whale          1933
# 999                               Cell 211       Daniel Monzón          2009
#
# ...
